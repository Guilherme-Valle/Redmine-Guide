# %% [markdown]
# # Welcome to Redmine. Look at the main page!

# %%
from guide_automator_function import *

get('localhost:84/')
takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18CF4198>

# %% [markdown]
# # Click on login!

# %%
highlight('.login')
takeScreenshot()
click('.login')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18A42D30>

# %% [markdown]
# # Now, insert the default Admin credentials

# %%
clearInput('#username')
fillIn('#username', 'admin')
clearInput('#password')
fillIn('#password', 'admin')
takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18A5DF28>

# %% [markdown]
# # Click on 'Entrar'!

# %%
highlight('input[type=submit]')
takeScreenshot()
click('input[type=submit]')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18A5D780>

# %% [markdown]
# # Now, lets see our projects, clicking on 'Projetos'

# %%
highlight('.projects')
takeScreenshot()
click('.projects')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18A60978>

# %% [markdown]
# # You don't have projects! Lets create one, clicking on 'Novo projeto'

# %%
highlight('a.icon-add')
takeScreenshot()
click('a.icon-add')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18A60908>

# %% [markdown]
# # Now, insert informations about your project!

# %%
fillIn('#project_name', 'New amazing project!')
fillIn('#project_description', 'I will change my life!')
takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18A5D6D8>

# %% [markdown]
# # Now, click on 'Criar'!

# %%
highlight('input[name="commit"]')
takeScreenshot()
click('input[name="commit"]')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18A6B8D0>

# %% [markdown]
# # Now, lets create a new user! Click on 'Administração'

# %%
highlight('.administration')
takeScreenshot()
click('.administration')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18A71550>

# %% [markdown]
# # Click on 'Usuários'

# %%
highlight('.users')
takeScreenshot()
click('.users')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18A71E10>

# %% [markdown]
# # Click on 'Novo usuário'

# %%
highlight('a.icon-add')
takeScreenshot()
click('a.icon-add')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18A6BE80>

# %% [markdown]
# # Now, insert the informations about the new user and click on 'Criar'

# %%
fillIn('#user_login', 'Joao_carlos')
fillIn('#user_firstname', 'Joao')
fillIn('#user_lastname', 'Carlos')
fillIn('#user_mail', 'joaocarlos@gmail.com')
fillIn('#user_password', 'abcdefg10')
fillIn('#user_password_confirmation', 'abcdefg10')
selectItemOnDropdownByVisibleText('#user_language', 'Português(Brasil)')
highlight('input[name="commit"]')
takeScreenshot()
click('input[name="commit"]')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18A78EB8>

# %% [markdown]
# # Now, click on 'Administração'

# %%
highlight('.administration')
takeScreenshot()
click('.administration')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18A60240>

# %% [markdown]
# # Click on 'Papéis e permissões'

# %%
highlight('.roles')
takeScreenshot()
click('.roles')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18A6B5C0>

# %% [markdown]
# # Now, to create a new role, click on 'Novo papel'

# %%
highlight('.icon-add')
takeScreenshot()
click('.icon-add')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18A71828>

# %% [markdown]
# # Fill in the fields and click on 'Criar'

# %%
fillIn('#role_name', 'Colaborador')
click('input[value="edit_project"]')
highlight('input[name="commit"]')
takeScreenshot()
click('input[name="commit"]')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18A606A0>

# %% [markdown]
# # Now, return to your project!

# %%
highlight('.projects')
takeScreenshot()
click('.projects')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18A611D0>

# %% [markdown]
# # Select your project!

# %%
highlight('#projects-index a')
takeScreenshot()
click('#projects-index a')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18A61278>

# %% [markdown]
# # Go to 'Configurações'

# %%
highlight('.settings')
takeScreenshot()
click('.settings')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18A612B0>

# %% [markdown]
# # Click on 'Membros'

# %%
highlight('#tab-members')
takeScreenshot()
click('#tab-members')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18A71B38>

# %% [markdown]
# # Select the new member, your paper and click on 'Adicionar'

# %%
sleep(2)
click('input[value="5"]')
click('input[name="membership[role_ids][]"]')
highlight('#member-add-submit')
takeScreenshot()
click('#member-add-submit')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18A60358>

# %% [markdown]
# # Now, go to 'Administracao'!

# %%
highlight('.administration')
takeScreenshot()
click('.administration')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18A60630>

# %% [markdown]
# # Click on "Situação das tarefas"

# %%
highlight('.issue-statuses')
takeScreenshot()
click('.issue-statuses')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18A78AC8>

# %% [markdown]
# # To create a new situation, click on 'Nova situação'

# %%
highlight('.icon-add')
takeScreenshot()
click('.icon-add')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18A5DDA0>

# %% [markdown]
# # Fill the name and click on 'Criar'

# %%
fillIn('#issue_status_name', 'Daily')
highlight('input[name="commit"]')
click('#issue_status_is_default')
takeScreenshot()
click('input[name="commit"]')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18A71518>

# %% [markdown]
# # Return to 'Administracao'

# %%
highlight('.administration')
takeScreenshot()
click('.administration')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FAE18A71FD0>

# %% [markdown]
# # Click on 'Tipos de tarefas'

# %%
highlight('.trackers')
takeScreenshot()
click('.trackers')

# %% [markdown]
# # To create a new issue type, click on 'Novo tipo'

# %%
highlight('.icon-add')
takeScreenshot()
click('.icon-add')

# %% [markdown]
# # Fill the name, select the situation and create

# %%
fillIn('#tracker_name', 'Main')
click('input[name="tracker[project_ids][]"]')
highlight('input[name="commit"]')
takeScreenshot()
click('input[name="commit"]')

# %% [markdown]
# # Return to 'Administração'

# %%
highlight('.administration')
takeScreenshot()
click('.administration')

# %% [markdown]
# # Click on 'Tipos & Categorias'

# %%
highlight('.enumerations')
takeScreenshot()
click('.enumerations')

# %% [markdown]
# # Click on 'Novo' under 'Prioridade das tarefas'

# %%
highlight('a[href="/enumerations/new?type=IssuePriority"]')
takeScreenshot()
click('a[href="/enumerations/new?type=IssuePriority"]')

# %% [markdown]
# # Fill in the name and click on 'Criar'

# %%
fillIn('#enumeration_name', 'Top')
highlight('input[name="commit"]')
takeScreenshot()
click('input[name="commit"]')

# %% [markdown]
# # Return to your project!

# %%
highlight('.projects')
takeScreenshot()
click('.projects')

# %% [markdown]
# # Select your project

# %%
highlight('#projects-index a')
takeScreenshot()
click('#projects-index a')

# %% [markdown]
# # Go to 'Configurações'

# %%
highlight('.settings')
takeScreenshot()
click('.settings')

# %% [markdown]
# # Select 'Categoria das tarefas'

# %%
highlight('#tab-categories')
takeScreenshot()
click('#tab-categories')

# %% [markdown]
# # Select 'Nova categoria'

# %%
sleep(1)
highlight('#tab-content-categories .icon-add')
takeScreenshot()
click('#tab-content-categories .icon-add')

# %% [markdown]
# # Fill the name, select the member and click on 'Criar'

# %%
fillIn('#issue_category_name', 'Daily')
selectItemOnDropdownByVisibleText('#issue_category_assigned_to_id', 'Joao Carlos')
highlight('input[name="commit"]')
takeScreenshot()
click('input[name="commit"]')

# %% [markdown]
# # Go to 'Nova Tarefa' on the tab of configurations

# %%
highlight('.new-issue')
takeScreenshot()
click('.new-issue')

# %% [markdown]
# # Go to 'Tarefas'

# %%
highlight('.issues')
takeScreenshot()
click('.issues')

# %% [markdown]
# # To create a new issue, click on 'Nova tarefa'

# %%
highlight('.new-issue')
takeScreenshot()
click('.new-issue')

# %% [markdown]
# # Fill the fields, select the responsible and click on 'Criar'

# %%
fillIn('#issue_subject', 'Write text')
selectItemOnDropdownByVisibleText('#issue_assigned_to_id', 'Joao Carlos')
highlight('input[name="commit"]')
takeScreenshot()
click('input[name="commit"]')

# %% [markdown]
# # Click again on 'Tarefas'

# %%
highlight('.issues')
takeScreenshot()
click('.issues')

# %% [markdown]
# # Click on the issue

# %%
highlight('#issue-1 > td.id > a')
takeScreenshot()
click('#issue-1 > td.id > a')

# %% [markdown]
# # Click on edit to change the name

# %%
highlight('.contextual:nth-child(1) .icon.icon-edit')
takeScreenshot()
click('.contextual:nth-child(1) .icon.icon-edit')

# %% [markdown]
# # Fill the title and click on 'Enviar'

# %%
fillIn('#issue_subject', 'New name')
highlight('#issue-form > input[type=submit]:nth-child(5)')
takeScreenshot()
click('#issue-form > input[type=submit]:nth-child(5)')

# %% [markdown]
# # Back to 'Tarefas'

# %%
highlight('.issues')
takeScreenshot()
click('.issues')

# %% [markdown]
# # Select the issue again

# %%
highlight('#issue-1 > td.id > a')
takeScreenshot()
click('#issue-1 > td.id > a')

# %% [markdown]
# # Click on 'Editar'

# %%
highlight('.contextual:nth-child(1) .icon.icon-edit')
takeScreenshot()
click('.contextual:nth-child(1) .icon.icon-edit')

# %% [markdown]
# # Change the item "Terminado" to '100%' and click on 'Enviar'

# %%
selectItemOnDropdownByVisibleText('#issue_done_ratio', '100 %')
highlight('#issue-form > input[type=submit]:nth-child(5)')
takeScreenshot()
click('#issue-form > input[type=submit]:nth-child(5)')
takeScreenshot()
close()
