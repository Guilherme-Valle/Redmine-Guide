# %% [markdown]
# # Welcome to Redmine. Look at the main page!

# %%
from guide_automator_function import *

get('localhost:84/')
takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F30EC0C4198>

# %% [markdown]
# # Click on login!

# %%
highlight('.login')
takeScreenshot()
click('.login')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F30EC024DA0>

# %% [markdown]
# # Now, insert the default Admin credentials

# %%
clearInput('#username')
fillIn('#username', 'admin')
clearInput('#password')
fillIn('#password', 'admin')
takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F30EC03EA90>

# %% [markdown]
# # Click on 'Entrar'!

# %%
highlight('#login-submit')
takeScreenshot()
click('#login-submit')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F30EC03E470>

# %% [markdown]
# # Now, you have to insert a new password!

# %%
clearInput('#password')
fillIn('#password', 'admin')
fillIn('#new_password', '12345678')
fillIn('#new_password_confirmation', '12345678')
takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F30EC03E668>

# %% [markdown]
# # Click on 'Aplicar'!

# %%
highlight('.tabular > input:nth-child(4)')
takeScreenshot()
click('.tabular > input:nth-child(4)')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F30EC03E9E8>

# %% [markdown]
# # Now, lets see our projects, clicking on 'Projetos'

# %%
highlight('.projects')
takeScreenshot()
click('.projects')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F30EC041E10>

# %% [markdown]
# # You don't have projects! Lets create one, clicking on 'Novo projeto'

# %%
highlight('a.icon')
takeScreenshot()
click('a.icon')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F30EC051D68>

# %% [markdown]
# # Now, insert informations about your project!

# %%
fillIn('#project_name', 'New amazing project!')
fillIn('#project_description', 'I will change my life!')
takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F30EC041630>

# %% [markdown]
# # Now, click on 'Criar'!

# %%
highlight('#new_project > input[type=submit]:nth-child(6)')
takeScreenshot()
click('#new_project > input[type="submit"]:nth-child(6)')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F30EC03EDA0>

# %% [markdown]
# # Now, lets create a new user! Click on 'Administração'

# %%
highlight('.administration')
takeScreenshot()
click('.administration')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F30EC054978>

# %% [markdown]
# # Click on 'Usuários'

# %%
highlight('#admin-menu > ul > li:nth-child(2) > a')
takeScreenshot()
click('#admin-menu > ul > li:nth-child(2) > a')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F30EC054F98>

# %% [markdown]
# # Click on 'Novo usuário'

# %%
highlight('#content > div.contextual > a')
takeScreenshot()
click('#content > div.contextual > a')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F30EC05B710>

# %% [markdown]
# # Now, insert the informations about the new user and click on 'Criar'

# %%
fillIn('#user_login', 'Joao_carlos')
fillIn('#user_firstname', 'Joao')
fillIn('#user_lastname', 'Carlos')
fillIn('#user_mail', 'joaocarlos@gmail.com')
fillIn('#user_password', 'abcdefg10')
fillIn('#user_password_confirmation', 'abcdefg10')
selectItemOnDropdownByVisibleText('#user_language', 'Portuguese (Português)')
highlight('#new_user > p > input[type=submit]:nth-child(1)')
takeScreenshot()
click('#new_user > p > input[type=submit]:nth-child(1)')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F30EC054FD0>

# %% [markdown]
# # Now, return to your project!

# %%
highlight('.projects')
takeScreenshot()
click('.projects')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F30EC05B3C8>

# %% [markdown]
# # Select your project!

# %%
highlight('#projects-index > ul > li > div > a')
takeScreenshot()
click('#projects-index > ul > li > div > a')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F30DC6D0C88>

# %% [markdown]
# # Go to 'Configurações'

# %%
highlight('#main-menu > ul > li:nth-child(12) > a')
takeScreenshot()
click('#main-menu > ul > li:nth-child(12) > a')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F30EC03EE80>

# %% [markdown]
# # Click on 'Membros'

# %%
highlight('#tab-members')
takeScreenshot()
click('#tab-members')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F30EC0417F0>

# %% [markdown]
# # Click on 'Novo membro'

# %%
highlight('#tab-content-members > p:nth-child(1) > a')
takeScreenshot()
click('#tab-content-members > p:nth-child(1) > a')
sleep(2)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F30EC03E160>

# %% [markdown]
# # Select the user and click on 'Adicionar'

# %%
click('#principals > label:nth-child(1) > input[type=checkbox]')
highlight('#member-add-submit')
takeScreenshot()
click('#member-add-submit')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F30EC051A20>
